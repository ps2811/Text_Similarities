# %% [markdown]
# """Example of Python client calling Knowledge Graph Search API."""
# import json
# import urllib
#
# api_key = open('.api_key').read()
# query = 'Taylor Swift'
# service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
# params = {
#     'query': query,
#     'limit': 10,
#     'indent': True,
#     'key': api_key,
# }
# url = service_url + '?' + urllib.urlencode(params)
# response = json.loads(urllib.urlopen(url).read())
# for element in response['itemListElement']:
#   print(element['result']['name'] + ' (' + str(element['resultScore']) + ')')

# %%
#Read the NACIS Codes
import pandas as pd
df = pd.read_excel('C:\\Users\\poojasharma8\\Documents\\My_Projects_NLP\\2017_NAICS_Descriptions.xlsx', sheetname='2017_NAICS_Descriptions', header=0)

# %%
NACIS_six_digit_codes = df[df.Six_Digit_Code.notnull()]
NACIS_six_digit_codes.head()
NACIS_six_digit_codes['Six_Digit_Code'] = NACIS_six_digit_codes['Six_Digit_Code'].astype(int)
NACIS_six_digit_codes = NACIS_six_digit_codes.drop('Six_Digit_Code', axis = 1)
NACIS_six_digit_codes.head()
#NACIS_six_digit_codes['NACIS'] = NACIS_six_digit_codes['Code'] + NACIS_six_digit_codes['Description']
# Out:
# C:\Users\poojasharma8\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Code                              Title  \
# 4   111110                    Soybean Farming
# 6   111120  Oilseed (except Soybean) Farming
# 8   111130          Dry Pea and Bean Farming
# 10  111140                      Wheat Farming
# 12  111150                      Corn Farming
#
#                                           Description
# 4   This industry comprises establishments primari...
# 6   This industry comprises establishments primari...
# 8   This industry comprises establishments primari...
# ...

# %%
len(NACIS_six_digit_codes)
# Out:
# 1057

# %%
import spacy

# %%
#!python -m spacy download en_core_web_lg

# %%
import en_core_web_lg
nlp = en_core_web_lg.load()

# %%
company_description = nlp(u'Deloitte Touche Tohmatsu Limited, commonly referred to as Deloitte, is a multinational professional services network. Deloitte is one of the "Big Four" accounting organizations and the largest professional services network in the world by revenue and number of professionals.')
NACIS_desc = nlp(u'This U.S. industry comprises establishments (except offices of CPAs) engaged in providing accounting services (except tax return preparation services only or payroll services only). These establishments may also provide tax return preparation or payroll services.  Accountant (except CPA) offices, bookkeeper offices, and billing offices are included in this industry.Cross-References.')
company_description2 = nlp(u'Deloitte is one of the "Big Four" accounting organizations and the largest professional services network in the world by revenue and number of professionals. Deloitte provides audit, tax, consulting, enterprise risk and financial advisory services with approximately 312,000 professionals globally.')
print("With high level description: ", company_description.similarity(NACIS_desc), '\n')
print("With more detailed description", company_description2.similarity(NACIS_desc), '\n')
# Out:
# With high level description:  0.8954507449066483
#
# With more detailed description 0.9107547971921564

# %%
list1= []
#NACIS_six_digit_codes['Description'] = nlp(NACIS_six_digit_codes['Description'])

for document in NACIS_six_digit_codes['Description']:
    doc_x = nlp(document)
    #print(doc_x)
    if doc_x.similarity(company_description2) >= .90:
        print(doc_x.similarity(company_description2), '\n')
        #print(doc_x)
# Out:
# 0.9042578013316293
#
# 0.9073910776765929
#
# 0.915814705131061
#
# 0.9312752300340379
#
# 0.9065898724957286
#
# 0.9245455598702331
#
# 0.922735302921191
#
# 0.9007562527610183
#
# 0.9029069534518878
#
# 0.9203141898841797
#
# 0.9187243037325407
#
# 0.9152591926580806
#
# 0.9107547538955393
#
# 0.9115190645336526
#
# 0.9015357387505895
#
# 0.9069718611315747
#
# 0.9459716879015996
#
# 0.9249243546041213
#
# 0.929381152058104
#
# 0.931237158065702
#
# 0.9125661597972773
#
# 0.9150257158764665
#
# 0.9000635467598046
#
# 0.9018909385004515
#
# 0.9109361758057158
#
# 0.9207387621728715
#
# 0.9155069444451924
#
# 0.9327512665918494
#
# 0.9256906763234667
#
# 0.9164404746229747
#
# 0.9317587866090098
#
# 0.9166988976156937
#
# 0.9461000991879222
#
# 0.9153371650779412
#
# 0.9026344127366004
#
# 0.9031658063712886
#
# 0.9149054880673414
#
# 0.9073824551005826
#
# 0.9043982147938997
#
# 0.900934561861083
#
# 0.9043056893641471
#
# 0.9140631734881255
#
# 0.9070254841191271
#
# ...

# %%
NACIS_dict = dict(zip(NACIS_six_digit_codes['Code'], NACIS_six_digit_codes['Description']))

# %%
list1= []
#NACIS_six_digit_codes['Description'] = nlp(NACIS_six_digit_codes['Description'])

for code in NACIS_dict:
    doc_x = nlp(NACIS_dict[code])
    #print(doc_x)
    if doc_x.similarity(company_description2) >= .95:
        print(doc_x.similarity(company_description2), '\n') 
        print(code, '\n')
        # 541219
        #print(doc_x)

# %%
NACIS_dict
# Out:
# {111110: 'This industry comprises establishments primarily engaged in growing soybeans and/or producing soybean seeds.\n\nCross-References.',
#  111120: 'This industry comprises establishments primarily engaged in growing fibrous oilseed producing plants and/or producing oilseed seeds, such as sunflower, safflower, flax, rape, canola, and sesame.\n\nCross-References. Establishments primarily engaged in--',
#  111130: 'This industry comprises establishments primarily engaged in growing dry peas, beans, and/or lentils.\n\nCross-References.',
#  111140: 'This industry comprises establishments primarily engaged in growing wheat and/or producing wheat seeds.\n\nCross-References.',
#  111150: 'This industry comprises establishments primarily engaged in growing corn (except sweet corn) and/or producing corn seeds.\n\nCross-References. Establishments primarily engaged in--',
# ...

# %%
NACIS_title1 = nlp(u"Insurance Carriers")
NACIS_title2 = nlp(u"Accounting, Tax Preparation, Bookkeeping, Payroll Services")

company_description = nlp(u"Deloitte Touche Tohmatsu Limited, commonly referred to as Deloitte, is a multinational professional services network. Deloitte is one of the Big Four accounting organizations the largest professional services network in the world by revenue number of professionals.")
print("With high level NACIS description: ", company_description.similarity(NACIS_title1), '\n')
print("With high level NACIS description: ", company_description.similarity(NACIS_title2), '\n')
# Out:
# With high level NACIS description:  0.5224665146919286
#
# With high level NACIS description:  0.7315788663815666
